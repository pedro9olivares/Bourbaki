# %% [markdown]
# # Estrategias de predicción con texto

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pedro9olivares/repo/blob/main/notebook.ipynb)
